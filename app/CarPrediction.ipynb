# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
data = pd.read_csv('cleaned_car.csv')

# %%
data.head()
# Out:
#            Brand    model  Year  Age  kmDriven Transmission   Owner  \
# 0        Renault   Triber  1900  124     88500    Automatic  second
# 1  Maruti Suzuki    Swift  1920  104     99000       Manual   first
# 2  Maruti Suzuki  Wagon-R  1931   93     87000       Manual   first
# 3       Mahindra     Jeep  1978   46     89000       Manual  second
# 4  Maruti Suzuki      800  1986   38     65000       Manual  second
#
#      FuelType   Price
# 0  Hybrid/CNG  440000
# 1      Petrol  519000
# 2  Hybrid/CNG  349000
# 3      Diesel  200000
# 4      Petrol  120000

# %%
data.tail()
# Out:
#                Brand        model  Year  Age  kmDriven Transmission  Owner  \
# 14859             MG        ASTOR  2024    0      5800       Manual  first
# 14860  Maruti Suzuki  Swift-Dzire  2024    0      5411       Manual  first
# 14861       Mahindra       XUV700  2024    0      5280    Automatic  first
# 14862         Toyota     Fortuner  2024    0      4000       Manual  first
# 14863     Land Rover     Defender  2024    0      3900    Automatic  first
#
#       FuelType     Price
# 14859   Petrol   1495000
# 14860   Petrol    260000
# 14861   Diesel   2599999
# 14862   Diesel   3899999
# 14863   Petrol  12700000

# %%
data.shape
# Out:
# (14864, 9)

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 14864
# Number of Columns 9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14864 entries, 0 to 14863
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         14864 non-null  object
#  1   model         14864 non-null  object
#  2   Year          14864 non-null  int64
#  3   Age           14864 non-null  int64
#  4   kmDriven      14864 non-null  int64
#  5   Transmission  14864 non-null  object
#  6   Owner         14864 non-null  object
#  7   FuelType      14864 non-null  object
#  8   Price         14864 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.0+ MB

# %%
data.isnull().sum()
# Out:
# Brand           0
# model           0
# Year            0
# Age             0
# kmDriven        0
# Transmission    0
# Owner           0
# FuelType        0
# Price           0
# dtype: int64

# %%
data.describe()
# Out:
#                Year           Age       kmDriven         Price
# count  14864.000000  14864.000000   14864.000000  1.486400e+04
# mean    2016.323601      7.676399   71366.527853  9.962367e+05
# std        4.340046      4.340046   58289.669366  1.585764e+06
# min     1900.000000      0.000000     120.000000  1.500000e+04
# 25%     2014.000000      5.000000   44198.500000  3.490000e+05
# 50%     2017.000000      7.000000   65000.000000  5.700000e+05
# 75%     2019.000000     10.000000   86000.000000  1.025000e+06
# max     2024.000000    124.000000  980002.000000  4.250000e+07

# %%
data.head(1)
# Out:
#      Brand   model  Year  Age  kmDriven Transmission   Owner    FuelType  \
# 0  Renault  Triber  1900  124     88500    Automatic  second  Hybrid/CNG
#
#     Price
# 0  440000

# %%
import datetime

# %%
date_time = datetime.datetime.now()

# %%
data['Age']=date_time.year - data['Year']

# %%
data.head()
# Out:
#            Brand    model  Year  Age  kmDriven Transmission   Owner  \
# 0        Renault   Triber  1900  125     88500    Automatic  second
# 1  Maruti Suzuki    Swift  1920  105     99000       Manual   first
# 2  Maruti Suzuki  Wagon-R  1931   94     87000       Manual   first
# 3       Mahindra     Jeep  1978   47     89000       Manual  second
# 4  Maruti Suzuki      800  1986   39     65000       Manual  second
#
#      FuelType   Price
# 0  Hybrid/CNG  440000
# 1      Petrol  519000
# 2  Hybrid/CNG  349000
# 3      Diesel  200000
# 4      Petrol  120000

# %%
data.drop('Year',axis=1,inplace=True)

# %%
data.head()
# Out:
#            Brand    model  Age  kmDriven Transmission   Owner    FuelType  \
# 0        Renault   Triber  125     88500    Automatic  second  Hybrid/CNG
# 1  Maruti Suzuki    Swift  105     99000       Manual   first      Petrol
# 2  Maruti Suzuki  Wagon-R   94     87000       Manual   first  Hybrid/CNG
# 3       Mahindra     Jeep   47     89000       Manual  second      Diesel
# 4  Maruti Suzuki      800   39     65000       Manual  second      Petrol
#
#     Price
# 0  440000
# 1  519000
# 2  349000
# 3  200000
# 4  120000

# %%
import seaborn as sns

# %%
sns.boxplot(data['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
sns.pairplot(data)

# %%
import matplotlib.pyplot as plt

numeric_data = data.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(18,18))
sns.heatmap(numeric_data.corr(), cmap="BuGn", annot=True)
# Out:
# <Axes: >

# %%
sorted(data['Price'],reverse=True)
# Out:
# [42500000,
#  39000000,
#  34800000,
#  30500000,
#  27750000,
#  26400000,
#  26000000,
#  24900000,
#  24700000,
#  24500000,
#  21500000,
#  18500000,
#  18500000,
#  17500000,
#  17500000,
#  17400000,
#  16500000,
#  16500000,
#  16500000,
#  16500000,
#  16500000,
#  16400000,
#  15900000,
#  15000000,
#  14900000,
#  14500000,
#  14500000,
#  14500000,
#  14000000,
#  13800000,
#  13600000,
#  13500000,
#  13300000,
#  13000000,
#  13000000,
#  12900000,
#  12900000,
#  12900000,
#  12700000,
#  12700000,
#  12600000,
#  12500000,
#  12500000,
#  12000000,
#  12000000,
#  12000000,
#  11900000,
#  11800000,
#  11800000,
#  11800000,
#  11800000,
#  11700000,
#  11700000,
#  11700000,
#  11500000,
#  11500000,
#  11500000,
#  11500000,
#  11500000,
#  11500000,
#  11200000,
#  11000000,
#  11000000,
#  11000000,
#  10900000,
#  10900000,
#  10900000,
#  10750000,
#  10700000,
#  10700000,
#  10700000,
#  10700000,
#  10500000,
#  10200000,
#  10000000,
#  10000000,
#  9900000,
#  9900000,
#  9850000,
#  9800000,
#  9800000,
#  9800000,
#  9800000,
#  9800000,
#  9750000,
#  9700000,
#  9700000,
#  9600000,
#  9575000,
#  9500000,
#  9500000,
#  9500000,
#  9500000,
#  9500000,
#  9500000,
#  9500000,
#  9500000,
#  9000000,
#  8999999,
#  8990000,
#  8900000,
#  8900000,
#  8900000,
#  8850000,
#  8700000,
#  8600000,
#  8500000,
#  8500000,
#  8500000,
#  8490000,
#  8475111,
#  8400000,
#  8400000,
#  8400000,
#  8300000,
#  8275000,
#  8200000,
#  8200000,
#  8200000,
#  8050000,
#  8050000,
#  8000000,
#  8000000,
#  8000000,
#  8000000,
#  8000000,
#  8000000,
#  8000000,
#  8000000,
#  8000000,
#  8000000,
#  7999000,
#  7950000,
#  7900000,
#  7900000,
#  7900000,
#  7875000,
#  7800000,
#  7750000,
#  7675000,
#  7600000,
#  7500000,
#  7500000,
#  7500000,
#  7500000,
#  7500000,
#  7500000,
#  7500000,
#  7500000,
#  7500000,
#  7499999,
#  7499000,
#  7495000,
#  7400000,
#  7300000,
#  7300000,
#  7200000,
#  7200000,
#  7200000,
#  7200000,
#  7200000,
#  7174999,
#  7150000,
#  7100000,
#  7000000,
#  7000000,
#  6999999,
#  6999999,
#  6975000,
#  6950000,
#  6900000,
#  6900000,
#  6891000,
#  6891000,
#  6891000,
#  6875000,
#  6850000,
#  6800000,
#  6800000,
#  6800000,
#  6800000,
#  6800000,
#  6790000,
#  6750000,
#  6700000,
#  6700000,
#  6700000,
#  6700000,
#  6699999,
#  6699999,
#  6650000,
#  6600000,
#  6600000,
#  6600000,
#  6550000,
#  6500000,
#  6500000,
#  6500000,
#  6500000,
#  6500000,
#  6499999,
#  6400000,
#  6300000,
#  6300000,
#  6300000,
#  6300000,
#  6300000,
#  6300000,
#  6300000,
#  6250000,
#  6250000,
#  6211000,
#  6200000,
#  6199000,
#  6175000,
#  6175000,
#  6150000,
#  6100000,
#  6090000,
#  6000000,
#  6000000,
#  6000000,
#  6000000,
#  6000000,
#  6000000,
#  6000000,
#  5975000,
#  5950000,
#  5950000,
#  5950000,
#  5950000,
#  5900000,
#  5900000,
#  5900000,
#  5900000,
#  5895000,
#  5850000,
#  5800000,
#  5800000,
#  5800000,
#  5800000,
#  5800000,
#  5800000,
#  5795000,
#  5750000,
#  5700000,
#  5650000,
#  5610000,
#  5600000,
#  5600000,
#  5600000,
#  5600000,
#  5600000,
#  5600000,
#  5600000,
#  5600000,
#  5600000,
#  5600000,
#  5575000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5499999,
#  5499000,
#  5495000,
#  5495000,
#  5495000,
#  5495000,
#  5490000,
#  5490000,
#  5475000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5390000,
#  5300000,
#  5300000,
#  5300000,
#  5300000,
#  5300000,
#  5300000,
#  5300000,
#  5299000,
#  5275000,
#  5275000,
#  5250000,
#  5200000,
#  5200000,
#  5200000,
#  5200000,
#  5195000,
#  5175111,
#  5150000,
#  5100000,
#  5100000,
#  5100000,
#  5100000,
#  5100000,
#  5100000,
#  5100000,
#  5000000,
#  5000000,
#  5000000,
#  5000000,
#  4999000,
#  4999000,
#  4990000,
#  4988000,
#  4988000,
#  4987000,
#  4980000,
#  4975000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4900000,
#  4900000,
#  4900000,
#  4900000,
#  4900000,
#  4900000,
#  4900000,
#  4850000,
#  4850000,
#  4850000,
#  4800000,
#  4800000,
#  4800000,
#  4800000,
#  4800000,
#  4800000,
#  4800000,
#  4795000,
#  4795000,
#  4775000,
#  4750000,
#  4750000,
#  4750000,
#  4750000,
#  4700000,
#  4700000,
#  4700000,
#  4700000,
#  4695000,
#  4675000,
#  4650000,
#  4650000,
#  4650000,
#  4650000,
#  4650000,
#  4650000,
#  4650000,
#  4599999,
#  4590000,
#  4575000,
#  4550000,
#  4550000,
#  4550000,
#  4525111,
#  4500000,
#  4500000,
#  4500000,
#  4500000,
#  4500000,
#  4500000,
#  4500000,
#  4500000,
#  4500000,
#  4500000,
#  4500000,
#  4500000,
#  4500000,
#  4500000,
#  4495000,
#  4490000,
#  4490000,
#  4490000,
#  4480000,
#  4475000,
#  4475000,
#  4475000,
#  4450000,
#  4450000,
#  4450000,
#  4450000,
#  4450000,
#  4450000,
#  4450000,
#  4450000,
#  4425000,
#  4400000,
#  4400000,
#  4400000,
#  4400000,
#  4400000,
#  4400000,
#  4400000,
#  4400000,
#  4400000,
#  4390000,
#  4390000,
#  4390000,
#  4385000,
#  4385000,
#  4375000,
#  4370000,
#  4350000,
#  4350000,
#  4350000,
#  4350000,
#  4350000,
#  4325111,
#  4300000,
#  4300000,
#  4300000,
#  4290000,
#  4285000,
#  4275000,
#  4250000,
#  4250000,
#  4250000,
#  4250000,
#  4211000,
#  4200000,
#  4200000,
#  4200000,
#  4200000,
#  4200000,
#  4200000,
#  4200000,
#  4200000,
#  4200000,
#  4199999,
#  4199000,
#  4195000,
#  4195000,
#  4190000,
#  4175000,
#  4175000,
#  4151111,
#  4150000,
#  4150000,
#  4150000,
#  4150000,
#  4150000,
#  4150000,
#  4100000,
#  4100000,
#  4100000,
#  4100000,
#  4100000,
#  4100000,
#  4100000,
#  4100000,
#  4100000,
#  4100000,
#  4100000,
#  4100000,
#  4100000,
#  4100000,
#  4100000,
#  4100000,
#  4099000,
#  4090000,
#  4050000,
#  4050000,
#  4050000,
#  4050000,
#  4050000,
#  4050000,
#  4050000,
#  4000000,
#  4000000,
#  4000000,
#  4000000,
#  4000000,
#  4000000,
#  4000000,
#  4000000,
#  4000000,
#  4000000,
#  4000000,
#  4000000,
#  4000000,
#  4000000,
#  3999999,
#  3999999,
#  3990000,
#  3985000,
#  3975000,
#  3975000,
#  3975000,
#  3975000,
#  3975000,
#  3975000,
#  3950000,
#  3950000,
#  3950000,
#  3950000,
#  3950000,
#  3950000,
#  3950000,
#  3950000,
#  3950000,
#  3950000,
#  3950000,
#  3950000,
#  3949000,
#  3900000,
#  3900000,
#  3900000,
#  3900000,
#  3900000,
#  3900000,
#  3900000,
#  3900000,
#  3900000,
#  3900000,
#  3899999,
#  3899999,
#  3895000,
#  3890000,
#  3890000,
#  3851000,
#  3851000,
#  3850000,
#  3850000,
#  3850000,
#  3850000,
#  3850000,
#  3850000,
#  3850000,
#  3850000,
#  3850000,
#  3850000,
#  3850000,
#  3850000,
#  3850000,
#  3850000,
#  3825000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3799000,
#  3799000,
#  3799000,
#  3799000,
#  3799000,
#  3790000,
#  3790000,
#  3790000,
#  3785111,
#  3780000,
#  3765000,
#  3751000,
#  3750000,
#  3750000,
#  3750000,
#  3750000,
#  3750000,
#  3750000,
#  3750000,
#  3750000,
#  3750000,
#  3749999,
#  3749000,
#  3749000,
#  3700000,
#  3700000,
#  3700000,
#  3700000,
#  3700000,
#  3700000,
#  3700000,
#  3700000,
#  3700000,
#  3699000,
#  3699000,
#  3695000,
#  3690000,
#  3690000,
#  3651000,
#  3650000,
#  3650000,
#  3649000,
#  3640000,
#  3600000,
#  3600000,
#  3600000,
#  3600000,
#  3600000,
#  3600000,
#  3600000,
#  3600000,
#  3600000,
#  3600000,
#  3599000,
#  3599000,
#  3599000,
#  3599000,
#  3598000,
#  3595000,
#  3585000,
#  3585000,
#  3583000,
#  3560000,
#  3550000,
#  3550000,
#  3550000,
#  3525000,
#  3500000,
#  3500000,
#  3500000,
#  3500000,
#  3500000,
#  3500000,
#  3500000,
#  3500000,
#  3500000,
#  3500000,
#  3500000,
#  3500000,
#  3500000,
#  3499999,
#  3499000,
#  3495000,
#  3495000,
#  3495000,
#  3495000,
#  3490000,
#  3485000,
#  3485000,
#  3475000,
#  3475000,
#  3475000,
#  3475000,
#  3475000,
#  3475000,
#  3475000,
#  3475000,
#  3475000,
#  3460000,
#  3450000,
#  3450000,
#  3450000,
#  3450000,
#  3450000,
#  3450000,
#  3450000,
#  3450000,
#  3450000,
#  3450000,
#  3450000,
#  3445000,
#  3444444,
#  3400000,
#  3400000,
#  3400000,
#  3400000,
#  3400000,
#  3400000,
#  3400000,
#  3400000,
#  3400000,
#  3400000,
#  3390000,
#  3390000,
#  3375000,
#  3375000,
#  3375000,
#  3350000,
#  3350000,
#  3350000,
#  3350000,
#  3350000,
#  3350000,
#  3349000,
#  3345000,
#  3333333,
#  3325000,
#  3325000,
#  3310000,
#  3300000,
#  3300000,
#  3300000,
#  3300000,
#  3300000,
#  3300000,
#  3300000,
#  3300000,
#  3300000,
#  3300000,
#  3300000,
#  3300000,
#  3299000,
#  3299000,
#  3298000,
#  3298000,
#  3298000,
#  3295000,
#  3295000,
#  3290000,
#  3290000,
#  3290000,
#  3290000,
#  3280000,
#  3275000,
#  3275000,
#  3250000,
#  3250000,
#  3250000,
#  3250000,
#  3250000,
#  3250000,
#  3250000,
#  3250000,
#  3250000,
#  3250000,
#  3249000,
#  3240000,
#  3200000,
#  3200000,
#  3200000,
#  3200000,
#  3200000,
#  3200000,
#  3200000,
#  3200000,
#  3200000,
#  3200000,
#  3200000,
#  3200000,
#  3199999,
#  3195000,
#  3190000,
#  3190000,
#  3190000,
#  3190000,
#  3175000,
#  3175000,
#  3175000,
#  3151000,
#  3151000,
#  3150000,
#  3150000,
#  3150000,
#  3150000,
#  3150000,
#  3150000,
#  3150000,
#  3150000,
#  3150000,
#  3150000,
#  3150000,
#  3150000,
#  3150000,
#  3149999,
#  3134000,
#  3134000,
#  3134000,
#  3125000,
#  3121000,
#  3100000,
#  3100000,
#  3100000,
#  3100000,
#  3100000,
#  3100000,
#  3100000,
#  3100000,
#  3100000,
#  3100000,
#  3100000,
#  3100000,
#  3099000,
#  3099000,
#  3098000,
#  3095000,
#  3090000,
#  3075000,
#  3075000,
#  3050000,
#  3050000,
#  3050000,
#  3050000,
#  3050000,
#  3050000,
#  3050000,
#  3045000,
#  3025000,
#  3025000,
#  3020000,
#  3000000,
#  3000000,
#  3000000,
#  3000000,
#  3000000,
#  3000000,
#  3000000,
#  3000000,
#  3000000,
#  3000000,
#  3000000,
#  3000000,
#  3000000,
#  3000000,
#  3000000,
#  2999999,
#  2999999,
#  2999999,
#  2999999,
#  2999000,
#  2999000,
#  2995000,
#  2995000,
#  2995000,
#  2995000,
#  2995000,
#  2995000,
#  2990000,
#  2990000,
#  2990000,
#  2990000,
#  2990000,
#  2985000,
#  2985000,
#  2980000,
#  2975000,
#  2975000,
#  2975000,
#  2975000,
#  2975000,
#  2975000,
#  2975000,
#  2970000,
#  2951000,
#  2951000,
#  2950000,
#  2950000,
#  2950000,
#  2950000,
#  2950000,
#  2950000,
#  2950000,
#  2950000,
#  2950000,
#  2950000,
#  2945111,
#  2925000,
#  2900000,
#  2900000,
#  2900000,
#  2900000,
#  2900000,
#  2900000,
#  2900000,
#  2900000,
#  2899999,
#  2899999,
#  2899000,
#  2890000,
#  2875000,
#  2875000,
#  2875000,
#  2875000,
#  2875000,
#  2875000,
#  2850000,
#  2850000,
#  2850000,
#  2850000,
#  2850000,
#  2850000,
#  2850000,
#  2850000,
#  2850000,
#  2850000,
#  2850000,
#  2850000,
#  2850000,
#  2850000,
#  2850000,
#  2850000,
#  2849000,
#  2845000,
#  2844000,
#  2825000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2799999,
#  2799999,
#  2799000,
#  2799000,
#  2795000,
#  2790000,
#  2790000,
#  2790000,
#  2785000,
#  2785000,
#  2775000,
#  2765000,
#  2751000,
#  2751000,
#  2751000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2745000,
#  2740000,
#  2740000,
#  2727000,
#  2725000,
#  2720000,
#  2710999,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2699999,
#  2699999,
#  2699999,
#  2699000,
#  2699000,
#  2699000,
#  2698000,
#  2695000,
#  2695000,
#  2695000,
#  2695000,
#  2695000,
#  2690000,
#  2690000,
#  2690000,
#  2690000,
#  2690000,
#  2685000,
#  ...]

# %%
data.shape
# Out:
# (14864, 8)

# %%
data.head(1)
# Out:
#      Brand   model  Age  kmDriven Transmission   Owner    FuelType   Price
# 0  Renault  Triber  125     88500    Automatic  second  Hybrid/CNG  440000

# %%
data['FuelType'].unique()
# Out:
# array(['Hybrid/CNG', 'Petrol', 'Diesel'], dtype=object)

# %%
data['FuelType'] = data['FuelType'].map({'Petrol':0,'Diesel':1,'Hybrid/CNG':2})

# %%
data['FuelType'].unique()
# Out:
# array([2, 0, 1])

# %%
data['Transmission'].unique()
# Out:
# array(['Automatic', 'Manual'], dtype=object)

# %%
data['Transmission'] =data['Transmission'].map({'Manual':0,'Automatic':1})

# %%
data.head()
# Out:
#            Brand    model  Age  kmDriven  Transmission   Owner  FuelType  \
# 0        Renault   Triber  125     88500             1  second         2
# 1  Maruti Suzuki    Swift  105     99000             0   first         0
# 2  Maruti Suzuki  Wagon-R   94     87000             0   first         2
# 3       Mahindra     Jeep   47     89000             0  second         1
# 4  Maruti Suzuki      800   39     65000             0  second         0
#
#     Price
# 0  440000
# 1  519000
# 2  349000
# 3  200000
# 4  120000

# %%
X = data.drop(['model','Price'],axis=1)
y = data['Price']

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
X_train = pd.get_dummies(X_train, drop_first=True)
X_test = pd.get_dummies(X_test, drop_first=True)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
xgb = GradientBoostingRegressor()
xgb.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
xg = XGBRegressor()
xg.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
X_test_aligned = X_test.reindex(columns=X_train.columns, fill_value=0)

y_pred1 = lr.predict(X_test_aligned)
y_pred2 = rf.predict(X_test_aligned)
y_pred3 = xgb.predict(X_test_aligned)
y_pred4 = xg.predict(X_test_aligned)

# %%
from sklearn import metrics

# %%
score1 = metrics.r2_score(y_test,y_pred1)
score2 = metrics.r2_score(y_test,y_pred2)
score3 = metrics.r2_score(y_test,y_pred3)
score4 = metrics.r2_score(y_test,y_pred4)

# %%
print(score1,score2,score3,score4)
# Out:
# 0.4717344633436368 0.5462341160087851 0.5621704979946935 0.6318451166152954

# %%
final_data = pd.DataFrame({'Models':['LR','RF','GBR','XG'],
             "R2_SCORE":[score1,score2,score3,score4]})

# %%
final_data
# Out:
#   Models  R2_SCORE
# 0     LR  0.471734
# 1     RF  0.546234
# 2    GBR  0.562170
# 3     XG  0.631845

# %%
# Convert object columns to one-hot encoding
X_encoded = pd.get_dummies(X, columns=['Brand', 'Owner'], drop_first=True)

# Fit the model with the transformed data
xg = XGBRegressor()
xg_final = xg.fit(X_encoded, y)

# %%
import joblib

# %%
joblib.dump(xg_final,'car_price_predictor.pkl')
# Out:
# ['car_price_predictor.pkl']

# %%
model = joblib.load('car_price_predictor.pkl')

# %%
import pandas as pd
data_new = pd.DataFrame({
    'Price':3.26,
        'kmDriven':27000,
            'FuelType':0,
                'Transmission':0,
                    'Owner':0,
                        'Age':8
                        },index=[0])

# %%
# Add a placeholder 'Brand' column to data_new to match the training data structure
data_new['Brand'] = 'Unknown'  # Replace 'Unknown' with a default value if needed

# Align data_new with the features used in training
data_new_processed = pd.get_dummies(data_new, columns=['Brand', 'Owner'], drop_first=True)
data_new_processed = data_new_processed.reindex(columns=X_encoded.columns, fill_value=0)

# Make prediction
model.predict(data_new_processed)
# Out:
# array([597091.2], dtype=float32)

# %%
# Align X_test with X_train columns
X_test_aligned = X_test.reindex(columns=X_train.columns, fill_value=0)

# Train the model and evaluate
xgb_model = XGBRegressor()
xgb_model.fit(X_train, y_train)
xgb_model.score(X_test_aligned, y_test)
# Out:
# 0.6318451166152954

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Transmission', y='Price', data=data)
plt.title('Average Price by Car Brand')
plt.xlabel('Transmission Type: 0- Automatic, 1- Manual')
plt.ylabel('Average Price (₹)')
plt.xticks(rotation=0)
plt.show()
